# %%
import os

# Github info
REPO_URL = "https://github.com/Xthan0411/18786_HW4.git"
REPO_NAME = "18786_HW4"

# %cd /content

if not os.path.exists(REPO_NAME):
    print(f"Repo doesn't exist, cloning {REPO_NAME}...")
    # !git clone {REPO_URL}
else:
    print(f"Repo exists, pulling")
    # %cd {REPO_NAME}
    # !git pull origin main


# %cd /content/{REPO_NAME}

# %%
# Task for FCSNN
# !python fcnn.py

from IPython.display import Image, display
import os

# %cd /content/{REPO_NAME}

if os.path.exists('fcnn_loss_curve.png'):
    display(Image('fcnn_loss_curve.png'))

if os.path.exists('fcnn_acc_curve.png'):
    display(Image('fcnn_acc_curve.png'))

if os.path.exists('fcnn_predictions.png'):
    display(Image('fcnn_predictions.png'))
